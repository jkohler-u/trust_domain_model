# %%
import plotting
import pandas as pd

# %%
#open csv

# %%
gt_df = pd.read_csv("/home/judith/Modeling_block/trust_domain_model/gt_df.csv")

speakerA = gt_df[gt_df['speaker'] == 'Speaker1']#
speakerA_session0 = speakerA[speakerA['session'] == 0]
ground_truth_tweet = speakerA_session0['is_true']
domain_tweet = speakerA_session0['domain']
ground_truth_tweet[:10]
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# 5    1
# 6    1
# 7    0
# 8    0
# 9    0
# Name: is_true, dtype: int64

# %%
sim_df = pd.read_csv("sim_df.csv")
speakerA = sim_df[sim_df['speaker'] == 'Speaker1']#
speakerA_session0 = speakerA[speakerA['session'] == 0]
part_choice = speakerA_session0['choice']
rt = speakerA_session0['rt']
q_0 = speakerA_session0['q_overall']
q_dA = speakerA_session0[speakerA_session0['domain' == 'A']]['q_dom']
q_dB = speakerA_session0[speakerA_session0['domain' == 'B']]['q_dom']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Modeling_block/trust_domain_model/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 7
#       5 rt = speakerA_session0['rt']
#       6 q_0 = speakerA_session0['q_overall']
# ----> 7 q_dA = speakerA_session0['domain' == 'A']['q_dom']
#       8 q_dB = speakerA_session0['domain' == 'B']['q_dom']
#
# File ~/Modeling_block/trust_domain_model/.venv/lib/python3.10/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/Modeling_block/trust_domain_model/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: False

# %%
plotting.plot_cumulative_accuracy_per_domain(tweet = ground_truth_tweet, domain = domain_tweet, choice = part_choice)

# %%
plotting.plot_cummulative_accuracy_rts(tweets = ground_truth_tweet, choices = part_choice, rts = rt)

# %%
plotting.plot_trust_switching(q_values = q_0, choices = part_choice, domain_labels=None)

# %%
plotting.plot_qvalues(qvalue_overall = q_0, qvalue_option1, qvalue_option2, show_legend=False, option_names=None):
